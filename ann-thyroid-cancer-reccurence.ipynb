# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.optimizers import Adamax, Adam
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("/kaggle/input/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv")
df.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# 1  T1a  N0  M0     I      Excellent       No
# 2  T1a  N0  M0     I      Excellent       No
# 3  T1a  N0  M0     I      Excellent       No
# 4  T1a  N0  M0     I      Excellent       No

# %% [markdown]
# # Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
#  15  Response              383 non-null    object
#  16  Recurred              383 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 51.0+ KB

# %%
df.describe()
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
categorical_columns = ['Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy', 'Thyroid Function',
                       'Physical Examination', 'Adenopathy', 'Pathology', 'Focality', 'Risk',
                       'T', 'N', 'M', 'Stage', 'Response','Recurred']
df = pd.get_dummies(df, columns = categorical_columns, drop_first=True)

# %%
age_column = df['Age'].values.reshape(-1, 1)

scaler = MinMaxScaler()
age_scaled = scaler.fit_transform(age_column)

df['Age'] = age_scaled

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 41 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Age                                               383 non-null    float64
#  1   Gender_M                                          383 non-null    bool
#  2   Smoking_Yes                                       383 non-null    bool
#  3   Hx Smoking_Yes                                    383 non-null    bool
#  4   Hx Radiothreapy_Yes                               383 non-null    bool
#  5   Thyroid Function_Clinical Hypothyroidism          383 non-null    bool
#  6   Thyroid Function_Euthyroid                        383 non-null    bool
#  7   Thyroid Function_Subclinical Hyperthyroidism      383 non-null    bool
#  8   Thyroid Function_Subclinical Hypothyroidism       383 non-null    bool
#  9   Physical Examination_Multinodular goiter          383 non-null    bool
#  10  Physical Examination_Normal                       383 non-null    bool
#  11  Physical Examination_Single nodular goiter-left   383 non-null    bool
#  12  Physical Examination_Single nodular goiter-right  383 non-null    bool
#  13  Adenopathy_Extensive                              383 non-null    bool
#  14  Adenopathy_Left                                   383 non-null    bool
#  15  Adenopathy_No                                     383 non-null    bool
#  16  Adenopathy_Posterior                              383 non-null    bool
#  17  Adenopathy_Right                                  383 non-null    bool
#  18  Pathology_Hurthel cell                            383 non-null    bool
#  19  Pathology_Micropapillary                          383 non-null    bool
#  20  Pathology_Papillary                               383 non-null    bool
#  21  Focality_Uni-Focal                                383 non-null    bool
#  22  Risk_Intermediate                                 383 non-null    bool
#  23  Risk_Low                                          383 non-null    bool
#  24  T_T1b                                             383 non-null    bool
#  25  T_T2                                              383 non-null    bool
#  26  T_T3a                                             383 non-null    bool
#  27  T_T3b                                             383 non-null    bool
#  28  T_T4a                                             383 non-null    bool
#  29  T_T4b                                             383 non-null    bool
#  30  N_N1a                                             383 non-null    bool
#  31  N_N1b                                             383 non-null    bool
#  32  M_M1                                              383 non-null    bool
#  33  Stage_II                                          383 non-null    bool
#  34  Stage_III                                         383 non-null    bool
#  35  Stage_IVA                                         383 non-null    bool
#  36  Stage_IVB                                         383 non-null    bool
#  37  Response_Excellent                                383 non-null    bool
#  38  Response_Indeterminate                            383 non-null    bool
#  39  Response_Structural Incomplete                    383 non-null    bool
#  40  Recurred_Yes                                      383 non-null    bool
# dtypes: bool(40), float64(1)
# memory usage: 18.1 KB

# %%
df.head()
# Out:
#         Age  Gender_M  Smoking_Yes  Hx Smoking_Yes  Hx Radiothreapy_Yes  \
# 0  0.179104     False        False           False                False
# 1  0.283582     False        False            True                False
# 2  0.223881     False        False           False                False
# 3  0.701493     False        False           False                False
# 4  0.701493     False        False           False                False
#
#    Thyroid Function_Clinical Hypothyroidism  Thyroid Function_Euthyroid  \
# 0                                     False                        True
# 1                                     False                        True
# 2                                     False                        True
# 3                                     False                        True
# 4                                     False                        True
#
#    Thyroid Function_Subclinical Hyperthyroidism  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Thyroid Function_Subclinical Hypothyroidism  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Physical Examination_Multinodular goiter  ...  N_N1b   M_M1  Stage_II  \
# 0                                     False  ...  False  False     False
# 1                                      True  ...  False  False     False
# 2                                     False  ...  False  False     False
# 3                                     False  ...  False  False     False
# 4                                      True  ...  False  False     False
#
#    Stage_III  Stage_IVA  Stage_IVB  Response_Excellent  \
# 0      False      False      False               False
# 1      False      False      False                True
# 2      False      False      False                True
# 3      False      False      False                True
# 4      False      False      False                True
#
#    Response_Indeterminate  Response_Structural Incomplete  Recurred_Yes
# 0                    True                           False         False
# 1                   False                           False         False
# 2                   False                           False         False
# 3                   False                           False         False
# 4                   False                           False         False
#
# [5 rows x 41 columns]

# %% [markdown]
# # Split the Dataset

# %%
X = df.drop(columns= ['Recurred_Yes'])
Y = df['Recurred_Yes']

# %%
X
# Out:
#           Age  Gender_M  Smoking_Yes  Hx Smoking_Yes  Hx Radiothreapy_Yes  \
# 0    0.179104     False        False           False                False
# 1    0.283582     False        False            True                False
# 2    0.223881     False        False           False                False
# 3    0.701493     False        False           False                False
# 4    0.701493     False        False           False                False
# ..        ...       ...          ...             ...                  ...
# 378  0.850746      True         True            True                 True
# 379  0.985075      True         True           False                 True
# 380  0.850746      True         True            True                False
# 381  0.686567      True         True            True                 True
# 382  0.776119      True         True           False                False
#
#      Thyroid Function_Clinical Hypothyroidism  Thyroid Function_Euthyroid  \
# 0                                       False                        True
# 1                                       False                        True
# 2                                       False                        True
# 3                                       False                        True
# 4                                       False                        True
# ..                                        ...                         ...
# 378                                     False                        True
# 379                                     False                        True
# 380                                     False                        True
# 381                                     False                       False
# 382                                     False                        True
#
#      Thyroid Function_Subclinical Hyperthyroidism  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ..                                            ...
# 378                                         False
# 379                                         False
# 380                                         False
# 381                                         False
# 382                                         False
#
#      Thyroid Function_Subclinical Hypothyroidism  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 378                                        False
# 379                                        False
# 380                                        False
# 381                                        False
# 382                                        False
#
#      Physical Examination_Multinodular goiter  ...  N_N1a  N_N1b   M_M1  \
# 0                                       False  ...  False  False  False
# 1                                        True  ...  False  False  False
# 2                                       False  ...  False  False  False
# 3                                       False  ...  False  False  False
# 4                                        True  ...  False  False  False
# ..                                        ...  ...    ...    ...    ...
# 378                                     False  ...  False   True   True
# 379                                      True  ...  False   True   True
# 380                                      True  ...  False   True   True
# 381                                      True  ...  False   True  False
# 382                                      True  ...  False   True  False
#
#      Stage_II  Stage_III  Stage_IVA  Stage_IVB  Response_Excellent  \
# 0       False      False      False      False               False
# 1       False      False      False      False                True
# 2       False      False      False      False                True
# 3       False      False      False      False                True
# 4       False      False      False      False                True
# ..        ...        ...        ...        ...                 ...
# 378     False      False      False       True               False
# 379     False      False      False       True               False
# 380     False      False      False       True               False
# 381     False      False       True      False               False
# 382     False      False       True      False               False
#
#      Response_Indeterminate  Response_Structural Incomplete
# 0                      True                           False
# 1                     False                           False
# 2                     False                           False
# 3                     False                           False
# 4                     False                           False
# ..                      ...                             ...
# 378                   False                           False
# 379                   False                            True
# 380                   False                            True
# 381                   False                            True
# 382                   False                            True
#
# [383 rows x 40 columns]

# %%
Y
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 378     True
# 379     True
# 380     True
# 381     True
# 382     True
# Name: Recurred_Yes, Length: 383, dtype: bool

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.9, shuffle=True, random_state=42)

# %% [markdown]
# # ANN model

# %%
model = Sequential([
    Dense(32, activation='relu', input_dim=40),
    Dropout(0.2),
    Dense(20, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='relu'),
    Dropout(0.2),
    Dense(5, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer= Adamax(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 32)             │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 20)             │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 5)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,243 (8.76 KB)
#  Trainable params: 2,243 (8.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, batch_size=32, epochs= 20,validation_split=0.1
                   , callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.6148 - loss: 0.6961 - val_accuracy: 0.6571 - val_loss: 0.6730
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7695 - loss: 0.6612 - val_accuracy: 0.6571 - val_loss: 0.6430
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7428 - loss: 0.6155 - val_accuracy: 0.6857 - val_loss: 0.5662
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7794 - loss: 0.5298 - val_accuracy: 0.9143 - val_loss: 0.3745
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8316 - loss: 0.4256 - val_accuracy: 0.9429 - val_loss: 0.2367
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8942 - loss: 0.3437 - val_accuracy: 0.9429 - val_loss: 0.1970
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8964 - loss: 0.2937 - val_accuracy: 0.9429 - val_loss: 0.1907
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9141 - loss: 0.2423 - val_accuracy: 0.9429 - val_loss: 0.1868
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9227 - loss: 0.2617 - val_accuracy: 0.9143 - val_loss: 0.1824
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9284 - loss: 0.2503 - val_accuracy: 0.9429 - val_loss: 0.1921
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9221 - loss: 0.2328 - val_accuracy: 0.9429 - val_loss: 0.1876
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9634 - loss: 0.1664 - val_accuracy: 0.9429 - val_loss: 0.1833
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9394 - loss: 0.2227 - val_accuracy: 0.9429 - val_loss: 0.1818
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9625 - loss: 0.1489 - val_accuracy: 0.9429 - val_loss: 0.1891
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9499 - loss: 0.2119 - val_accuracy: 0.9429 - val_loss: 0.1863
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9440 - loss: 0.2110 - val_accuracy: 0.9429 - val_loss: 0.1897
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9362 - loss: 0.2451 - val_accuracy: 0.9429 - val_loss: 0.2144
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9551 - loss: 0.1812 - val_accuracy: 0.9429 - val_loss: 0.2365
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9540 - loss: 0.1962 - val_accuracy: 0.9429 - val_loss: 0.2226
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9629 - loss: 0.1698 - val_accuracy: 0.9429 - val_loss: 0.2119

# %%
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = [i+1 for i in range(len(tr_acc))]

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs, tr_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'g', label='Valid Loss')
plt.title('Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs, tr_acc, 'r', label='Train Accuracy')
plt.plot(epochs, val_acc, 'g', label='Valid Accuracy')
plt.title('Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step

# %%
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[28,  0],
#        [ 0, 11]])

# %%
sns.heatmap(cm, annot=True)
plt.show()

# %% [markdown]
# # Save the model

# %%
model.save('model.h5')
